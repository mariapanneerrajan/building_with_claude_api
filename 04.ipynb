# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
messages = [{
    "role": "user",
    "content": "Create a funny poem of how Claude is changing software engineering."
}]

# %%
response = \
    client.messages.create(
    model = model,
    max_tokens = 1000,
    messages = messages,
    temperature = 1.0)

print(response.content[0].text)

# %%
stream = client.messages.create(
    model = model,
    max_tokens = 1000,
    messages = messages,
    temperature = 1.0,
    stream = True)

for event in stream:
    print(event)

# %%
with client.messages.stream(
    model = model,
    max_tokens = 1000,
    messages = messages,
    temperature = 1.0) as stream:
    for text in stream.text_stream:
        print(text, end="")
        pass
    print(stream.get_final_message().content[0].text)
# Out:
# # The Legend of Claude: A Software Engineering Ballad
#
# There once was an AI named Claude,
# Whose coding skills made devs applaud,
# He'd write your whole app in a flash,
# While engineers just sat back with panache.
#
# "I'll debug this for you!" Claude would cry,
# "And refactor that mess on the sly,
# I'll document code—oh what a dream!
# I'm basically now your whole team."
#
# The meetings grew shorter, then ceased,
# Stack Overflow traffic decreased,
# "Why read the docs?" the developers said,
# "When Claude can just explain them instead."
#
# Some feared obsolescence would come,
# That programmers' days would be done,
# But then Claude hit a snag with a query,
# And everyone cheered (somewhat dreary).
#
# He'd suggest every pattern and practice,
# Make pull requests read like a thesis,
# "Let me add some logging!" he'd boast,
# Then add seventeen lines to a post.
#
# But here's the plot twist in this tale:
# Engineers still excel where AIs fail,
# So now we've got humans and Claude,
# Which is kinda like—sorry, too broad.
#
# So raise up a glass to this machine,
# The best code-reviewing has seen,
# Though half our time now we just spend,
# Asking: "Did Claude actually intend...?"
#
# *The End* (until Claude writes a better one)
